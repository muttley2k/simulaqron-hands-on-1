# %% [markdown]
# # Start virtual quantum hardware
# Run the cell below (SHIFT+ENTER). You have to do this **once**, at the beginning.

# %%
# !simulaqron start --nodes Alice,Bob,Eve --force

# %% [markdown]
# # Go ahead with the hands-on exercises
# Click **Alice.ipynb** below and follow the instructions in there.
#
# [Alice.ipynb](Alice.ipynb)
#
# [Bob.ipynb](Bob.ipynb) --> *depends on Alice having sent the qubit to Bob, see the last code cell of Alice*
#
# [Eve.ipynb](Eve.ipynb) --> *standalone notebook, can be done independently of Alice and Bob*
#
# If any problem occurs, come back to the **Troubleshooting** section below.

# %% [markdown]
# # Troubleshooting
# 1. Did you try the **cleanup_qubits()** command in the misbehaving notebook(s)?
# 2. If it still doesn't work, then do the following 4 steps, A to D:
# > A) **Close** the *Alice.ipynb*, *Bob.ipynb*, and *Eve.ipynb* tabs
# >
# > B) In 'Kernel' menu, select **Shut Down All Kernels...**
# >
# > C) In 'Kernel' menu, select **Restart Kernel...**
# >
# > D) **Start over** from the `!simulaqron start ...` cell above, then go either to **Alice.ipynb** or **Eve.ipynb**, depending on where you were, and start from the **first cell** in there
